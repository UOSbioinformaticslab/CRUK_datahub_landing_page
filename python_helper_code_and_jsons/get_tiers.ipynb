# %%
from get_tiers import build_tree
import json

# %%
with open('../src/utils/deepmerge.json', 'r') as f:
    data = json.load(f)

# %%
print(build_tree(data))
# Out:
# - welcome
# - version
# - summary
#   - title
#   - shortTitle
#   - doiName
#   - abstract
#   - keywords
#   - controlledKeywords
#   - contactPoint
#   - datasetType
#   - description
#   - publisher
#     - name
#     - gatewayId
#     - rorId
#     - identifier
#     - logo
#     - description
#   - populationSize
#   - datasetSubType
#   - inPipeline
#   - dataCustodian
# - documentation
#   - description
#   - associatedMedia
#   - inPipeline
# - datasetFilters
# - structuralMetadata
#   - name
#   - description
#   - columns
#     - name
#     - dataType
#     - description
#     - sensitive
#     - values
#       - name
#       - description
#       - frequency
#   - size
# - erd
#   - image
#   - description
# - otherDataTypes
#   - title
#   - description
#   - format
# - coverage
#   - typicalAgeRangeMin
#   - typicalAgeRangeMax
#   - datasetCompleteness
# - provenance
#   - temporal
#     - startDate
#     - endDate
#     - timeLag
#     - accrualPeriodicity
# ...
